# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

df = pd.read_csv("balanced_dataset.csv")

print(df.describe())

sb.pairplot(df, kind="scatter", hue="best_strategy")
plt.show()
# Out:
#            states     actions  uncertainty      sparse     tot_tests  \
# count  184.000000  184.000000   184.000000  184.000000    184.000000
# mean    29.043478    5.657609    49.103261    0.565217  11559.445652
# std     12.707653    2.547290    18.096136    0.497081  10898.779508
# min     10.000000    2.000000    20.000000    0.000000    400.000000
# 25%     16.750000    3.000000    31.000000    0.000000   2665.000000
# 50%     30.500000    5.000000    51.000000    1.000000   7760.000000
# 75%     40.250000    8.000000    64.250000    1.000000  17114.000000
# max     50.000000   10.000000    80.000000    1.000000  48020.000000
#
#             prior       score
# count  184.000000  184.000000
# mean     0.548913    0.112551
# std      0.498959    0.045015
# min      0.000000    0.052118
# 25%      0.000000    0.079568
# 50%      1.000000    0.099929
# 75%      1.000000    0.130558
# max      1.000000    0.328079
